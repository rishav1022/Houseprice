# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas import DataFrame,Series
import seaborn as sns
import scipy.stats as stats

# %%
train=pd.read_csv('/content/drive/MyDrive/train.csv')
test=pd.read_csv('/content/drive/MyDrive/test.csv')

# %%
train.shape,test.shape
# Out:
# ((1460, 81), (1459, 80))

# %%
pd.options.display.max_rows=None
pd.options.display.max_columns=None

# %%
train.isnull().sum()
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          8
# MasVnrArea          8
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           37
# BsmtCond           37
# BsmtExposure       38
# BsmtFinType1       37
# BsmtFinSF1          0
# BsmtFinType2       38
# BsmtFinSF2          0
# BsmtUnfSF           0
# TotalBsmtSF         0
# Heating             0
# HeatingQC           0
# ...

# %%
test.isna().sum()
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            4
# LotFrontage       227
# LotArea             0
# Street              0
# Alley            1352
# LotShape            0
# LandContour         0
# Utilities           2
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         1
# Exterior2nd         1
# MasVnrType         16
# MasVnrArea         15
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           44
# BsmtCond           45
# BsmtExposure       44
# BsmtFinType1       42
# BsmtFinSF1          1
# BsmtFinType2       42
# BsmtFinSF2          1
# BsmtUnfSF           1
# TotalBsmtSF         1
# Heating             0
# HeatingQC           0
# ...

# %%
train.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
# Alley             object
# LotShape          object
# LandContour       object
# Utilities         object
# LotConfig         object
# LandSlope         object
# Neighborhood      object
# Condition1        object
# Condition2        object
# BldgType          object
# HouseStyle        object
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# RoofStyle         object
# RoofMatl          object
# Exterior1st       object
# Exterior2nd       object
# MasVnrType        object
# MasVnrArea       float64
# ExterQual         object
# ExterCond         object
# Foundation        object
# BsmtQual          object
# BsmtCond          object
# BsmtExposure      object
# BsmtFinType1      object
# BsmtFinSF1         int64
# BsmtFinType2      object
# BsmtFinSF2         int64
# ...

# %%
train.describe().T
# Out:
#                 count           mean           std      min        25%  \
# Id             1460.0     730.500000    421.610009      1.0     365.75
# MSSubClass     1460.0      56.897260     42.300571     20.0      20.00
# LotFrontage    1201.0      70.049958     24.284752     21.0      59.00
# LotArea        1460.0   10516.828082   9981.264932   1300.0    7553.50
# OverallQual    1460.0       6.099315      1.382997      1.0       5.00
# OverallCond    1460.0       5.575342      1.112799      1.0       5.00
# YearBuilt      1460.0    1971.267808     30.202904   1872.0    1954.00
# YearRemodAdd   1460.0    1984.865753     20.645407   1950.0    1967.00
# MasVnrArea     1452.0     103.685262    181.066207      0.0       0.00
# BsmtFinSF1     1460.0     443.639726    456.098091      0.0       0.00
# BsmtFinSF2     1460.0      46.549315    161.319273      0.0       0.00
# BsmtUnfSF      1460.0     567.240411    441.866955      0.0     223.00
# ...

# %%
def missing_values_table(df):
        # Total missing values
        mis_val = df.isnull().sum()
        
        # Percentage of missing values
        mis_val_percent = 100 * df.isnull().sum() / len(df)
        
        # Make a table with the results
        mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
        
        # Rename the columns
        mis_val_table_ren_columns = mis_val_table.rename(
        columns = {0 : 'Missing Values', 1 : '% of Total Values'})
        
        # Sort the table by percentage of missing descending
        mis_val_table_ren_columns = mis_val_table_ren_columns[
            mis_val_table_ren_columns.iloc[:,1] != 0].sort_values(
        '% of Total Values', ascending=False).round(1)
        
        # Print some summary information
        print ("Your selected dataframe has " + str(df.shape[1]) + " columns.\n"      
            "There are " + str(mis_val_table_ren_columns.shape[0]) +
              " columns that have missing values.")
        
        #Return the dataframe with missing information
        return mis_val_table_ren_columns

# %%
missing_values_table(train)
# Out:
# Your selected dataframe has 81 columns.
# There are 19 columns that have missing values.
#               Missing Values  % of Total Values
# PoolQC                  1453               99.5
# MiscFeature             1406               96.3
# Alley                   1369               93.8
# Fence                   1179               80.8
# FireplaceQu              690               47.3
# LotFrontage              259               17.7
# GarageType                81                5.5
# GarageYrBlt               81                5.5
# GarageFinish              81                5.5
# GarageQual                81                5.5
# GarageCond                81                5.5
# BsmtExposure              38                2.6
# BsmtFinType2              38                2.6
# BsmtFinType1              37                2.5
# BsmtCond                  37                2.5
# BsmtQual                  37                2.5
# MasVnrArea                 8                0.5
# ...

# %%
missing_values_table(test)
# Out:
# Your selected dataframe has 80 columns.
# There are 33 columns that have missing values.
#               Missing Values  % of Total Values
# PoolQC                  1456               99.8
# MiscFeature             1408               96.5
# Alley                   1352               92.7
# Fence                   1169               80.1
# FireplaceQu              730               50.0
# LotFrontage              227               15.6
# GarageCond                78                5.3
# GarageYrBlt               78                5.3
# GarageQual                78                5.3
# GarageFinish              78                5.3
# GarageType                76                5.2
# BsmtCond                  45                3.1
# BsmtExposure              44                3.0
# BsmtQual                  44                3.0
# BsmtFinType1              42                2.9
# BsmtFinType2              42                2.9
# MasVnrType                16                1.1
# ...

# %%
train1=train.copy()
test1=test.copy()

# %%
train1.drop(['PoolQC','MiscFeature','Alley','Fence','FireplaceQu'],axis=1,inplace=True)
test1.drop(['PoolQC','MiscFeature','Alley','Fence','FireplaceQu'],axis=1,inplace=True)

# %%
train1.shape,test1.shape
# Out:
# ((1460, 76), (1459, 75))

# %%
missing_values_table(train1)
# Out:
# Your selected dataframe has 76 columns.
# There are 14 columns that have missing values.
#               Missing Values  % of Total Values
# LotFrontage              259               17.7
# GarageType                81                5.5
# GarageYrBlt               81                5.5
# GarageFinish              81                5.5
# GarageQual                81                5.5
# GarageCond                81                5.5
# BsmtExposure              38                2.6
# BsmtFinType2              38                2.6
# BsmtQual                  37                2.5
# BsmtCond                  37                2.5
# BsmtFinType1              37                2.5
# MasVnrType                 8                0.5
# MasVnrArea                 8                0.5
# Electrical                 1                0.1

# %%
train1.dropna(subset=['Electrical','MasVnrArea','MasVnrType'],inplace=True,how='any')

# %%
missing_values_table(train1)
# Out:
# Your selected dataframe has 76 columns.
# There are 11 columns that have missing values.
#               Missing Values  % of Total Values
# LotFrontage              257               17.7
# GarageType                81                5.6
# GarageYrBlt               81                5.6
# GarageFinish              81                5.6
# GarageQual                81                5.6
# GarageCond                81                5.6
# BsmtExposure              38                2.6
# BsmtFinType2              38                2.6
# BsmtQual                  37                2.5
# BsmtCond                  37                2.5
# BsmtFinType1              37                2.5

# %%
from sklearn_pandas import CategoricalImputer
from sklearn.impute import SimpleImputer

# %%
cat_imputer=CategoricalImputer()
mean_imputer=SimpleImputer(strategy='mean')

# %%
num_cols=train1.select_dtypes(include=np.number).columns
cat_cols=train1.select_dtypes(include=object).columns
tnum_cols=test1.select_dtypes(include=np.number).columns
tcat_cols=test1.select_dtypes(include=object).columns

# %%
num_cols,cat_cols
# Out:
# (Index(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
#         'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
#         'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
#         'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#         'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
#         'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
#         'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',
#         'MiscVal', 'MoSold', 'YrSold', 'SalePrice'],
#        dtype='object'),
#  Index(['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities',
#         'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#         'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#         'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
# ...

# %%
num_train=train1[num_cols]
cat_train=train1[cat_cols]
# num_test=test1[tnum_cols]
# cat_test=test1[tcat_cols]

# %%
num_test=test1[tnum_cols]
cat_test=test1[tcat_cols]

# %%
test1.head(2)
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0  1461          20       RH         80.0    11622   Pave      Reg
# 1  1462          20       RL         81.0    14267   Pave      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl        NAmes      Feedr
# 1         Lvl    AllPub    Corner       Gtl        NAmes       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     1Story            5            6       1961
# 1       Norm     1Fam     1Story            6            6       1958
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          1961     Gable  CompShg     VinylSd     VinylSd       None
# 1          1958       Hip  CompShg     Wd Sdng     Wd Sdng    BrkFace
#
#    MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# ...

# %%
mean_imputer.fit_transform(num_train)
mean_imputer.fit_transform(num_test)
# Out:
# array([[1.461e+03, 2.000e+01, 8.000e+01, ..., 0.000e+00, 6.000e+00,
#         2.010e+03],
#        [1.462e+03, 2.000e+01, 8.100e+01, ..., 1.250e+04, 6.000e+00,
#         2.010e+03],
#        [1.463e+03, 6.000e+01, 7.400e+01, ..., 0.000e+00, 3.000e+00,
#         2.010e+03],
#        ...,
#        [2.917e+03, 2.000e+01, 1.600e+02, ..., 0.000e+00, 9.000e+00,
#         2.006e+03],
#        [2.918e+03, 8.500e+01, 6.200e+01, ..., 7.000e+02, 7.000e+00,
#         2.006e+03],
#        [2.919e+03, 6.000e+01, 7.400e+01, ..., 0.000e+00, 1.100e+01,
#         2.006e+03]])

# %%
test1['GarageType'] = cat_imputer.fit_transform(test1['GarageType'])
test1['GarageYrBlt'] = cat_imputer.fit_transform(test1['GarageYrBlt'])
test1['GarageFinish'] = cat_imputer.fit_transform(test1['GarageFinish'])

test1['GarageQual'] = cat_imputer.fit_transform(test1['GarageQual'])

test1['GarageCond'] = cat_imputer.fit_transform(test1['GarageCond'])

test1['BsmtCond'] = cat_imputer.fit_transform(test1['BsmtCond'])

test1['BsmtQual'] = cat_imputer.fit_transform(test1['BsmtQual'])

test1['BsmtExposure'] = cat_imputer.fit_transform(test1['BsmtExposure'])

test1['BsmtFinType1'] = cat_imputer.fit_transform(test1['BsmtFinType1'])

test1['BsmtFinType2'] = cat_imputer.fit_transform(test1['BsmtFinType2'])

test1['MasVnrType'] = cat_imputer.fit_transform(test1['MasVnrType'])

test1['MasVnrArea'] = cat_imputer.fit_transform(test1['MasVnrArea'])

test1['MSZoning'] = cat_imputer.fit_transform(test1['MSZoning'])

# %%
test1['BsmtFullBath'] = cat_imputer.fit_transform(test1['BsmtFullBath'])
# From Faculty (Olympus) to Everyone 12:27 PM
train1['GarageType'] = cat_imputer.fit_transform(train1['GarageType'])
train1['GarageYrBlt'] = cat_imputer.fit_transform(train1['GarageYrBlt'])
train1['GarageFinish'] = cat_imputer.fit_transform(train1['GarageFinish'])

train1['GarageQual'] = cat_imputer.fit_transform(train1['GarageQual'])

train1['GarageCond'] = cat_imputer.fit_transform(train1['GarageCond'])

train1['BsmtCond'] = cat_imputer.fit_transform(train1['BsmtCond'])

train1['BsmtQual'] = cat_imputer.fit_transform(train1['BsmtQual'])

train1['BsmtExposure'] = cat_imputer.fit_transform(train1['BsmtExposure'])

train1['BsmtFinType1'] = cat_imputer.fit_transform(train1['BsmtFinType1'])

train1['BsmtFinType2'] = cat_imputer.fit_transform(train1['BsmtFinType2'])

# %%
missing_values_table(test1)
# Out:
# Your selected dataframe has 75 columns.
# There are 14 columns that have missing values.
#               Missing Values  % of Total Values
# LotFrontage              227               15.6
# Utilities                  2                0.1
# BsmtHalfBath               2                0.1
# Functional                 2                0.1
# Exterior1st                1                0.1
# Exterior2nd                1                0.1
# BsmtFinSF1                 1                0.1
# BsmtFinSF2                 1                0.1
# BsmtUnfSF                  1                0.1
# TotalBsmtSF                1                0.1
# KitchenQual                1                0.1
# GarageCars                 1                0.1
# GarageArea                 1                0.1
# SaleType                   1                0.1

# %%
missing_values_table(train1)
# Out:
# Your selected dataframe has 76 columns.
# There are 0 columns that have missing values.
# Empty DataFrame
# Columns: [Missing Values, % of Total Values]
# Index: []

# %%
train1['LotFrontage']=mean_imputer.fit_transform(train1[['LotFrontage']])

# %%
missing_values_table(test1)
# Out:
# Your selected dataframe has 75 columns.
# There are 0 columns that have missing values.
# Empty DataFrame
# Columns: [Missing Values, % of Total Values]
# Index: []

# %%
test1['LotFrontage']=mean_imputer.fit_transform(test1[['LotFrontage']])

# %%
test1['BsmtHalfBath']=mean_imputer.fit_transform(test1[['BsmtHalfBath']])

# %%
test1['BsmtFinSF1']=mean_imputer.fit_transform(test1[['BsmtFinSF1']])

# %%
test1['BsmtFinSF2']=mean_imputer.fit_transform(test1[['BsmtFinSF2']])

# %%
test1['BsmtUnfSF']=mean_imputer.fit_transform(test1[['BsmtUnfSF']])

# %%
test1['TotalBsmtSF']=mean_imputer.fit_transform(test1[['TotalBsmtSF']])

# %%
test1['GarageCars']=mean_imputer.fit_transform(test1[['GarageCars']])

# %%
test1['GarageArea']=mean_imputer.fit_transform(test1[['GarageArea']])

# %%
test1['SaleType']=cat_imputer.fit_transform(test1['SaleType'])

# %%
test1['KitchenQual']=cat_imputer.fit_transform(test1['KitchenQual'])

# %%
test1['Utilities']=cat_imputer.fit_transform(test1['Utilities'])

# %%
test1['Functional']=cat_imputer.fit_transform(test1['Functional'])

# %%
test1['Exterior1st']=cat_imputer.fit_transform(test1['Exterior1st'])

# %%
test1['Exterior2nd']=cat_imputer.fit_transform(test1['Exterior2nd'])

# %%
train1.shape,test1.shape
# Out:
# ((1451, 76), (1459, 75))

# %%
combine=pd.concat([train1,test1],ignore_index=True)

# %%
combine.shape
# Out:
# (2910, 76)

# %%
dummydata=pd.get_dummies(combine,drop_first=True)

# %%
dummydata.shape
# Out:
# (2910, 234)

# %%
train_data=dummydata.iloc[:1451]
test_data=dummydata.iloc[1451:]

# %%
test_data = test_data.drop(['SalePrice'], axis = 1)

# %%
test_data.shape
# Out:
# (1459, 233)

# %%
X_train = train_data.drop(['Id','SalePrice'], axis = 1)
y_train = train_data['SalePrice']

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components = 10)
principalcomp = pca.fit_transform(X_train)
principaltraindata = pd.DataFrame(data = principalcomp)

# %%
principaltestcomp = pca.fit_transform(test_data)
principaltestdata = pd.DataFrame(data = principaltestcomp)

# %%
from xgboost import XGBRegressor
model = XGBRegressor()

# %%
model.fit(principaltraindata,y_train)
# Out:
# [08:24:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor()

# %%
pred = model.predict(principaltestdata)

# %%
test_pred = pd.DataFrame(pred)

# %%
test_pred.columns = ['SalePrice']

# %%
test_pred.head()
# Out:
#        SalePrice
# 0  116490.445312
# 1  434708.062500
# 2  256523.859375
# 3  214086.812500
# 4  181455.390625

# %%
test_pred.index = test_data.index

# %%
test_pred['Id'] = test_data['Id']

# %%
test_pred.shape
# Out:
# (1459, 2)

# %%
test_pred.head()
# Out:
#           SalePrice    Id
# 1451  116490.445312  1461
# 1452  434708.062500  1462
# 1453  256523.859375  1463
# 1454  214086.812500  1464
# 1455  181455.390625  1465

# %%
test_pred.to_csv('submission.csv',index=False)
